# %% [markdown]
# # Visualisation

# %%
import json
from pandas import json_normalize
import requests
import pandas as pd
import yfinance as yf
from datetime import datetime
import time
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
# Configuration to set so that all the Seaborn figs come out with this size
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# Matplotlib inline to visualize Matplotlib graphs
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %% [markdown]
# ## Graphs Phase 1

# %%
df_all = pd.read_csv (r'1df_all.csv')
df_all.boxplot(column="no_of_comments").set(title='Distribution of the stocks based on no of comments')
# Out:
# [Text(0.5, 1.0, 'Distribution of the stocks based on no of comments')]

# %%
df_all_sorted_top_10 = pd.read_csv (r'2df_all_sorted_top_10.csv')
barplot = sns.barplot(x="no_of_comments", y="ticker", data=df_all_sorted_top_10).set(title='Stocks with the highest no of comments')

# %%
df_all_sorted_noc = pd.read_csv (r'3df_all_sorted_noc.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_all_sorted_noc).set(title='Total no of comments per day')

# %% [markdown]
# ## Graphs Phase 2

# %%
hist_bbby = pd.read_csv (r'4hist_bbby_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_bbby).set(title='Price evolution of BBBY, rebased on 100, Bearish stock')
# Out:
# [Text(0.5, 1.0, 'Price evolution of BBBY, rebased on 100, Bearish stock')]

# %%
hist_gme = pd.read_csv (r'5hist_gme_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_gme).set(title='Price evolution of GME, rebased on 100, Bullish stock')
# Out:
# [Text(0.5, 1.0, 'Price evolution of GME, rebased on 100, Bullish stock')]

# %%
hist_nvda = pd.read_csv (r'6hist_nvda_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_nvda).set(title='Price evolution of NVDA, rebased on 100, Bearish stock')
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %% [markdown]
# ## Graphs Phase 3

# %%
hist_snp_clean_2 = pd.read_csv (r'7hist_snp_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_snp_clean_2).set(title='Price evolution of S&P500, rebased on 100')
# Out:
# [Text(0.5, 1.0, 'Price evolution of S&P500, rebased on 100')]

# %%
hist_nsd_clean_2 = pd.read_csv (r'8hist_nsd_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_nsd_clean_2).set(title='Price evolution of the NASDAQ, rebased on 100')
# Out:
# [Text(0.5, 1.0, 'Price evolution of the NASDAQ, rebased on 100')]

# %%
hist_snp_clean_2 = pd.read_csv (r'9hist_snp_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_snp_clean_2).set(title='Price evolution of S&P500, rebased on 100')
# Out:
# [Text(0.5, 1.0, 'Price evolution of S&P500, rebased on 100')]

# %%
hist_nsd_clean_2 = pd.read_csv (r'10hist_nsd_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_snp_clean_2).set(title='Price evolution of the NASDAQ, rebased on 100')
# Out:
# [Text(0.5, 1.0, 'Price evolution of the NASDAQ, rebased on 100')]

# %% [markdown]
# ## Graphs Phase 4

# %%
df_data_sample_2_BBBY = pd.read_csv (r'11df_data_sample_2_BBBY.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_data_sample_2_BBBY).set(title='No of comments of BBBY 4 days before/after the selected date')

# %%
df_data_sample_2_NVDA = pd.read_csv (r'12df_data_sample_2_NVDA.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_data_sample_2_NVDA).set(title='No of comments of NVDA 4 days before/after the selected date')

# %%
df_data_sample_2_GME = pd.read_csv (r'13df_data_sample_2_GME.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_data_sample_2_GME).set(title='No of comments of GME 4 days before/after the selected date')
