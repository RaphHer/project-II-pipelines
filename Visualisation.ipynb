# %% [markdown]
# # Visualisation

# %%
import json
from pandas import json_normalize
import requests
import pandas as pd
import yfinance as yf
from datetime import datetime
import time
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
# Configuration to set so that all the Seaborn figs come out with this size
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# Matplotlib inline to visualize Matplotlib graphs
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %% [markdown]
# ## Graphs Phase 1

# %%
df_all = pd.read_csv (r'1df_all.csv')
df_all.boxplot(column="no_of_comments")
# Out:
# <AxesSubplot: >

# %%
sns.countplot(x=df_all.no_of_comments)
# Out:
# <AxesSubplot: xlabel='no_of_comments', ylabel='count'>

# %%
df_all_sorted_top_10 = pd.read_csv (r'2df_all_sorted_top_10.csv')
barplot = sns.barplot(x="no_of_comments", y="ticker", data=df_all_sorted_top_10)

# %%
df_all_sorted_noc = pd.read_csv (r'3df_all_sorted_noc.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_all_sorted_noc)

# %% [markdown]
# ## Graphs Phase 2

# %%
hist_bbby = pd.read_csv (r'4hist_bbby_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_bbby)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %%
hist_gme = pd.read_csv (r'5hist_gme_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_gme)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %%
hist_nvda = pd.read_csv (r'6hist_nvda_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_nvda)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %% [markdown]
# ## Graphs Phase 3

# %%
hist_snp_clean_2 = pd.read_csv (r'7hist_snp_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_snp_clean_2)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %%
hist_nsd_clean_2 = pd.read_csv (r'8hist_nsd_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_nsd_clean_2)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %%
hist_snp_clean_2 = pd.read_csv (r'9hist_snp_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_snp_clean_2)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %%
hist_nsd_clean_2 = pd.read_csv (r'10hist_nsd_clean_2.csv')
sns.lineplot(x="Date", y="rebased at 100", data=hist_snp_clean_2)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='rebased at 100'>

# %% [markdown]
# ## Graphs Phase 4

# %%
df_data_sample_2_BBBY = pd.read_csv (r'11df_data_sample_2_BBBY.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_data_sample_2_BBBY)

# %%
df_data_sample_2_NVDA = pd.read_csv (r'12df_data_sample_2_NVDA.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_data_sample_2_NVDA)

# %%
df_data_sample_2_GME = pd.read_csv (r'13df_data_sample_2_GME.csv')
barplot = sns.barplot(x='Date', y = "no_of_comments", data= df_data_sample_2_GME)
