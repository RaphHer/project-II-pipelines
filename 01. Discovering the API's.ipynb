# %% [markdown]
# # Discovering the two API's
#
# For this project, I will use two APIs named YFinance and a Reddit API.
#
# The YFinance API is an APA that gives access to a wide range of financial data on listed companies from Yahoo Finance. Some documentation [Doc1](https://algotrading101.com/learn/yahoo-finance-api-guide/) [Doc2](https://github.com/ranaroussi/yfinance)
#
# Reddit's API is an API that scrapes the 50 most popular actions on the site. The popularity of the share is measured by the number of mentions of the stake on the site. John Ludhi developed the API, and [here](https://tradestie.com/apps/reddit/api/) you can find some additional information.

# %% [markdown]
# I will now discover the two APIs and the information and functions they can deliver.

# %% [markdown]
# ## Yahoo Finance

# %%
import yfinance as yf  #importing the yfinance library

# %%
#Calling a stock, here I will call the Microsoft stock with its ticker MSFT
msft = yf.Ticker("MSFT")

# %%
msft.info  #info function gives all the information on a given stock
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 221000,
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.',
#  'city': 'Redmond',
#  'phone': '425 882 8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'fax': '425 706 7329',
#  'industry': 'Software—Infrastructure',
#  'ebitdaMargins': 0.49418998,
#  'profitMargins': 0.36686,
#  'grossMargins': 0.68402,
#  'operatingCashflow': 89034997760,
#  'revenueGrowth': 0.124,
#  'operatingMargins': 0.42055,
#  'ebitda': 97982996480,
#  'targetLowPrice': 275,
#  'recommendationKey': 'buy',
#  'grossProfits': 135620000000,
#  'freeCashflow': 49479000064,
#  'targetMedianPrice': 315,
#  'currentPrice': 242.12,
#  'earningsGrowth': 0.031,
#  'currentRatio': 1.785,
#  'returnOnAssets': 0.14919,
#  'numberOfAnalystOpinions': 44,
#  'targetMeanPrice': 323.38,
#  'debtToEquity': 47.075,
#  'returnOnEquity': 0.47151002,
#  'targetHighPrice': 411,
#  'totalCash': 104748998656,
#  'totalDebt': 78399995904,
#  'totalRevenue': 198269992960,
#  'totalCashPerShare': 14.045,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 26.45,
#  'quickRatio': 1.567,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 8.974,
#  'beta3Year': None,
#  'enterpriseToEbitda': 18.16,
#  '52WeekChange': -0.21422774,
#  'morningStarRiskRating': None,
#  'forwardEps': 11.82,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7457889792,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 22.313,
#  'sharesShort': 34921823,
#  'sharesPercentSharesOut': 0.0047,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1656547200,
#  'heldPercentInstitutions': 0.71756,
#  'netIncomeToCommon': 72737996800,
#  'trailingEps': 9.65,
#  'lastDividendValue': 0.62,
#  'SandP52WeekChange': -0.17819631,
#  'priceToBook': 10.851073,
#  'heldPercentInsiders': 0.00079,
#  'nextFiscalYearEnd': 1719705600,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': 1.29,
#  'sharesShortPreviousMonthDate': 1661904000,
#  'floatShares': 7451105190,
#  'beta': 0.960206,
#  'enterpriseValue': 1779355746304,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1660694400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.017,
#  'priceToSalesTrailing12Months': 9.1073,
#  'dateShortInterest': 1664496000,
#  'pegRatio': 1.59,
#  'ytdReturn': None,
#  'forwardPE': 20.483925,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0047,
#  'sharesShortPriorMonth': 40544332,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 236.15,
#  'regularMarketOpen': 234.74,
#  'twoHundredDayAverage': 274.764,
#  'trailingAnnualDividendYield': 0.0105018,
#  'payoutRatio': 0.2508,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 242.88,
#  'navPrice': None,
#  'averageDailyVolume10Day': 27741000,
#  'regularMarketPreviousClose': 236.15,
#  'fiftyDayAverage': 253.3614,
#  'trailingAnnualDividendRate': 2.48,
#  'open': 234.74,
#  'toCurrency': None,
#  'averageVolume10days': 27741000,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.72,
#  'exDividendDate': 1668556800,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 234.5,
#  'currency': 'USD',
#  'trailingPE': 25.090157,
#  'regularMarketVolume': 25235911,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1805704232960,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 25689992,
#  'dayLow': 234.5,
#  'ask': 241.73,
#  'askSize': 3100,
#  'volume': 25235911,
#  'fiftyTwoWeekHigh': 349.67,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.2,
#  'fiftyTwoWeekLow': 219.13,
#  'bid': 241.34,
#  'tradeable': False,
#  'dividendYield': 0.0112,
#  'bidSize': 800,
#  'dayHigh': 242.88,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 242.12,
#  'preMarketPrice': 243.21,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %%
# history function is giving the price evolution - "max" is since IPO until today

hist = msft.history(period="max") 
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.055536    0.063703    0.055536    0.060980
# 1986-03-14 00:00:00-05:00    0.060980    0.064247    0.060980    0.063158
# 1986-03-17 00:00:00-05:00    0.063158    0.064792    0.063158    0.064247
# 1986-03-18 00:00:00-05:00    0.064247    0.064792    0.062069    0.062613
# 1986-03-19 00:00:00-05:00    0.062613    0.063158    0.060980    0.061524
# ...                               ...         ...         ...         ...
# 2022-10-17 00:00:00-04:00  235.820007  238.960007  235.139999  237.529999
# 2022-10-18 00:00:00-04:00  243.240005  243.929993  235.369995  238.500000
# 2022-10-19 00:00:00-04:00  237.039993  239.610001  234.289993  236.479996
# 2022-10-20 00:00:00-04:00  235.770004  241.309998  234.869995  236.149994
# 2022-10-21 00:00:00-04:00  234.740005  243.000000  234.500000  242.119995
#
#                                Volume  Dividends  Stock Splits
# Date
# 1986-03-13 00:00:00-05:00  1031788800        0.0           0.0
# 1986-03-14 00:00:00-05:00   308160000        0.0           0.0
# 1986-03-17 00:00:00-05:00   133171200        0.0           0.0
# 1986-03-18 00:00:00-05:00    67766400        0.0           0.0
# 1986-03-19 00:00:00-05:00    47894400        0.0           0.0
# ...                               ...        ...           ...
# 2022-10-17 00:00:00-04:00    28142300        0.0           0.0
# 2022-10-18 00:00:00-04:00    26329600        0.0           0.0
# 2022-10-19 00:00:00-04:00    19985700        0.0           0.0
# 2022-10-20 00:00:00-04:00    21811000        0.0           0.0
# 2022-10-21 00:00:00-04:00    26280900        0.0           0.0
#
# [9229 rows x 7 columns]

# %%
msft.recommendations #Recommendations from equity research analysts
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2022-10-19 11:52:49       Citigroup            Buy              main
# 2022-10-19 13:34:44     Cowen & Co.     Outperform              main
# 2022-10-20 09:42:07   Piper Sandler     Overweight              main
# 2022-10-20 10:59:41      Rosenblatt            Buy              main
# 2022-10-20 11:49:17             UBS            Buy              main
#
# [406 rows x 4 columns]

# %%
etf = ['AAPL','IBM'] #gives the price evolution of two stocks or more
tit = yf.download(tickers=etf, period='max')
tit
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   AAPL         IBM        AAPL         IBM        AAPL
# Date
# 1962-01-02         NaN    1.652503         NaN    7.291268         NaN
# 1962-01-03         NaN    1.666947         NaN    7.355003         NaN
# 1962-01-04         NaN    1.650338         NaN    7.281708         NaN
# 1962-01-05         NaN    1.617835         NaN    7.138305         NaN
# 1962-01-08         NaN    1.587502         NaN    7.004461         NaN
# ...                ...         ...         ...         ...         ...
# 2022-10-17  142.410004  121.519997  142.410004  121.519997  142.899994
# 2022-10-18  143.750000  122.940002  143.750000  122.940002  146.699997
# 2022-10-19  143.860001  122.510002  143.860001  122.510002  144.949997
# 2022-10-20  143.389999  128.300003  143.389999  128.300003  145.889999
# 2022-10-21  147.270004  129.899994  147.270004  129.899994  147.850006
#
#                                Low                    Open              \
#                    IBM        AAPL         IBM        AAPL         IBM
# Date
# 1962-01-02    7.374124         NaN    7.291268         NaN    7.374124
# 1962-01-03    7.355003         NaN    7.291268         NaN    7.291268
# 1962-01-04    7.355003         NaN    7.278521         NaN    7.355003
# 1962-01-05    7.272148         NaN    7.125558         NaN    7.272148
# 1962-01-08    7.131931         NaN    6.947100         NaN    7.131931
# ...                ...         ...         ...         ...         ...
# 2022-10-17  122.879997  140.270004  121.430000  141.070007  121.800003
# 2022-10-18  123.940002  140.610001  121.820000  145.490005  123.000000
# 2022-10-19  123.940002  141.500000  121.989998  141.690002  122.360001
# 2022-10-20  128.960007  142.649994  125.150002  143.020004  126.250000
# 2022-10-21  130.850006  142.649994  127.589996  142.869995  128.389999
#
#                 Volume
#                   AAPL       IBM
# Date
# 1962-01-02         NaN    407940
# 1962-01-03         NaN    305955
# 1962-01-04         NaN    274575
# 1962-01-05         NaN    384405
# 1962-01-08         NaN    572685
# ...                ...       ...
# 2022-10-17  85250900.0   5458600
# 2022-10-18  99136600.0   5120300
# 2022-10-19  61758300.0   5906600
# 2022-10-20  64522000.0  13623100
# 2022-10-21  86464700.0   7200400
#
# [15308 rows x 12 columns]

# %% [markdown]
# ## Reddit API

# %%
import requests

# %%
res = requests.get("https://tradestie.com/api/v1/apps/reddit") #Calling the API
res #200 means no problem, the API works
# Out:
# <Response [200]>

# %%
test_1 = res.json()
test_1
# Out:
# [{'no_of_comments': 11,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.371,
#   'ticker': 'BABA'},
#  {'no_of_comments': 8,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.026,
#   'ticker': 'UK'},
#  {'no_of_comments': 6,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.13,
#   'ticker': 'GME'},
#  {'no_of_comments': 3,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.04,
#   'ticker': 'AAPL'},
#  {'no_of_comments': 3,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'TECH'},
#  {'no_of_comments': 3,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.22,
#   'ticker': 'PLTR'},
#  {'no_of_comments': 3,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.257,
#   'ticker': 'TSLA'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.147,
#   'ticker': 'IRS'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.259,
#   'ticker': 'IQ'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.211,
#   'ticker': 'RE'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.392,
#   'ticker': 'BBBY'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.151,
#   'ticker': 'TA'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'TQQQ'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.415,
#   'ticker': 'SQQQ'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.45,
#   'ticker': 'TLT'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.196,
#   'ticker': 'TV'},
#  {'no_of_comments': 2,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.025,
#   'ticker': 'PPT'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'ADP'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.305,
#   'ticker': 'MA'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'TEAM'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.114,
#   'ticker': 'MSFT'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.558,
#   'ticker': 'MTG'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.209,
#   'ticker': 'ON'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.555,
#   'ticker': 'JP'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.362,
#   'ticker': 'XOM'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'TSM'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.098,
#   'ticker': 'CLF'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'PYPL'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.349,
#   'ticker': 'WB'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.336,
#   'ticker': 'ONE'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.16,
#   'ticker': 'TWO'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.293,
#   'ticker': 'AMZN'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.964,
#   'ticker': 'CNS'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.252,
#   'ticker': 'BB'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.725,
#   'ticker': 'BEST'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.718,
#   'ticker': 'RCI'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.013,
#   'ticker': 'HR'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'BEAT'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.625,
#   'ticker': 'TIL'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.478,
#   'ticker': 'ETN'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.298,
#   'ticker': 'AI'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.721,
#   'ticker': 'FSR'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.19,
#   'ticker': 'AMD'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.244,
#   'ticker': 'RC'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': 0.0,
#   'ticker': 'JACK'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.637,
#   'ticker': 'MAN'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.823,
#   'ticker': 'MS'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.177,
#   'ticker': 'BY'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.109,
#   'ticker': 'NVDA'},
#  {'no_of_comments': 1,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.421,
#   'ticker': 'NICE'}]

# %% [markdown]
# The information given by the API are:
# - no comments (how many times was the stock mentioned)
# - sentiment (Bullish - stock's price is expected to go up/Bearish - stock's price is expected to go down)
# - sentiment score - measures if the bullish/bearish sentiment is very pronounced or not
# - ticker - name of the stock on the stock exchange market
