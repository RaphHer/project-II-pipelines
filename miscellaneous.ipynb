# %%
import json
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
import pandas as pd

data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
response = requests.get('https://api.github.com/events')
 
data = pd.DataFrame(response.json())
data.head(10)
# Out:
#             id               type  \
# 0  24750879001          PushEvent
# 1  24750878976          PushEvent
# 2  24750878960          PushEvent
# 3  24750878998          PushEvent
# 4  24750879024          PushEvent
# 5  24750878971          PushEvent
# 6  24750878994          PushEvent
# 7  24750878823          PushEvent
# 8  24750878986  IssueCommentEvent
# 9  24750878984        CreateEvent
#
#                                                actor  \
# 0  {'id': 108565747, 'login': 'HyunKyu-Song', 'di...
# 1  {'id': 98070882, 'login': 'seryozha1989', 'dis...
# 2  {'id': 41898282, 'login': 'github-actions[bot]...
# 3  {'id': 17869732, 'login': 'moiify', 'display_l...
# 4  {'id': 41898282, 'login': 'github-actions[bot]...
# 5  {'id': 81522233, 'login': 'Dagore-dev', 'displ...
# 6  {'id': 102279897, 'login': 'Rithicksubramanian...
# 7  {'id': 41898282, 'login': 'github-actions[bot]...
# 8  {'id': 108627643, 'login': 'rocknswimmer', 'di...
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']
 
flat = flatten(data, nested_columns)
flat.head(10)
# Out:
#             id               type  public            created_at   actor_id  \
# 0  24750879001          PushEvent    True  2022-10-21T13:39:12Z  108565747
# 1  24750878976          PushEvent    True  2022-10-21T13:39:12Z   98070882
# 2  24750878960          PushEvent    True  2022-10-21T13:39:12Z   41898282
# 3  24750878998          PushEvent    True  2022-10-21T13:39:12Z   17869732
# 4  24750879024          PushEvent    True  2022-10-21T13:39:12Z   41898282
# 5  24750878971          PushEvent    True  2022-10-21T13:39:12Z   81522233
# 6  24750878994          PushEvent    True  2022-10-21T13:39:12Z  102279897
# 7  24750878823          PushEvent    True  2022-10-21T13:39:12Z   41898282
# 8  24750878986  IssueCommentEvent    True  2022-10-21T13:39:12Z  108627643
# 9  24750878984        CreateEvent    True  2022-10-21T13:39:12Z  115105583
#
#            actor_login actor_display_login actor_gravatar_id  \
# 0         HyunKyu-Song        HyunKyu-Song
# ...

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']
 
flat = flatten(data, nested_columns)
flat.head(10)
# Out:
#             id               type  public            created_at   actor_id  \
# 0  24750879001          PushEvent    True  2022-10-21T13:39:12Z  108565747
# 1  24750878976          PushEvent    True  2022-10-21T13:39:12Z   98070882
# 2  24750878960          PushEvent    True  2022-10-21T13:39:12Z   41898282
# 3  24750878998          PushEvent    True  2022-10-21T13:39:12Z   17869732
# 4  24750879024          PushEvent    True  2022-10-21T13:39:12Z   41898282
# 5  24750878971          PushEvent    True  2022-10-21T13:39:12Z   81522233
# 6  24750878994          PushEvent    True  2022-10-21T13:39:12Z  102279897
# 7  24750878823          PushEvent    True  2022-10-21T13:39:12Z   41898282
# 8  24750878986  IssueCommentEvent    True  2022-10-21T13:39:12Z  108627643
# 9  24750878984        CreateEvent    True  2022-10-21T13:39:12Z  115105583
#
#            actor_login actor_display_login actor_gravatar_id  \
# 0         HyunKyu-Song        HyunKyu-Song
# ...

# %%
'https://tradestie.com/api/v1/apps/reddit'

# %%
res = requests.get("https://tradestie.com/api/v1/apps/reddit")
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'[{"no_of_comments":48,"sentiment":"Bullish","sentiment_score":0.553,"ticker":"SNAP"},{"no_of_comments":40,"sentiment":"Bullish","sentiment_score":0.257,"ticker":"TSLA"},{"no_of_comments":19,"sentiment":"Bullish","sentiment_score":0.026,"ticker":"UK"},{"no_of_comments":13,"sentiment":"Bullish","sentiment_score":0.13,"ticker":"GME"},{"no_of_comments":9,"sentiment":"Bearish","sentiment_score":-0.34,"ticker":"TWTR"},{"no_of_comments":7,"sentiment":"Bullish","sentiment_score":0.218,"ticker":"QQQ"},{"no_of_comments":6,"sentiment":"Bullish","sentiment_score":0.02,"ticker":"GM"},{"no_of_comments":6,"sentiment":"Bearish","sentiment_score":-0.45,"ticker":"TLT"},{"no_of_comments":6,"sentiment":"Bearish","sentiment_score":-0.392,"ticker":"BBBY"},{"no_of_comments":5,"sentiment":"Bullish","sentiment_score":0.984,"ticker":"NFLX"},{"no_of_comments":5,"sentiment":"Bullish","sentiment_score":0.19,"ticker":"AMD"},{"no_of_comments":5,"sentiment":"Bullish","sentiment_score":0.625,"ticker":"AXP"},{"no_o
# ...

# %%
res.json()
# Out:
# [{'no_of_comments': 48,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.553,
#   'ticker': 'SNAP'},
#  {'no_of_comments': 40,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.257,
#   'ticker': 'TSLA'},
#  {'no_of_comments': 19,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.026,
#   'ticker': 'UK'},
#  {'no_of_comments': 13,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.13,
#   'ticker': 'GME'},
#  {'no_of_comments': 9,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.34,
#   'ticker': 'TWTR'},
#  {'no_of_comments': 7,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.218,
#   'ticker': 'QQQ'},
#  {'no_of_comments': 6,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.02,
#   'ticker': 'GM'},
#  {'no_of_comments': 6,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.45,
#   'ticker': 'TLT'},
#  {'no_of_comments': 6,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.392,
#   'ticker': 'BBBY'},
#  {'no_of_comments': 5,
# ...

# %%
date = "2022-04-03"
res = requests.get(f"https://tradestie.com/api/v1/apps/reddit?date={date}")
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'[{"no_of_comments":131,"sentiment":"Bullish","sentiment_score":0.13,"ticker":"GME"},{"no_of_comments":90,"sentiment":"Bullish","sentiment_score":0.159,"ticker":"AMC"},{"no_of_comments":25,"sentiment":"Bullish","sentiment_score":0.257,"ticker":"TSLA"},{"no_of_comments":21,"sentiment":"Bullish","sentiment_score":0.67,"ticker":"WISH"},{"no_of_comments":12,"sentiment":"Bullish","sentiment_score":0.218,"ticker":"QQQ"},{"no_of_comments":10,"sentiment":"Bullish","sentiment_score":0.196,"ticker":"TV"},{"no_of_comments":9,"sentiment":"Bullish","sentiment_score":0.186,"ticker":"HMHC"},{"no_of_comments":8,"sentiment":"Bullish","sentiment_score":0.34,"ticker":"PAA"},{"no_of_comments":6,"sentiment":"Bullish","sentiment_score":0.875,"ticker":"AA"},{"no_of_comments":6,"sentiment":"Bullish","sentiment_score":0.015,"ticker":"OXY"},{"no_of_comments":5,"sentiment":"Bullish","sentiment_score":0.336,"ticker":"ONE"},{"no_of_comments":5,"sentiment":"Bullish","sentiment_score":0.19,"ticker":"AMD"},{"no_of
# ...

# %%
res.json()
# Out:
# [{'no_of_comments': 131,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.13,
#   'ticker': 'GME'},
#  {'no_of_comments': 90,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.159,
#   'ticker': 'AMC'},
#  {'no_of_comments': 25,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.257,
#   'ticker': 'TSLA'},
#  {'no_of_comments': 21,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.67,
#   'ticker': 'WISH'},
#  {'no_of_comments': 12,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.218,
#   'ticker': 'QQQ'},
#  {'no_of_comments': 10,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.196,
#   'ticker': 'TV'},
#  {'no_of_comments': 9,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.186,
#   'ticker': 'HMHC'},
#  {'no_of_comments': 8,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.34,
#   'ticker': 'PAA'},
#  {'no_of_comments': 6,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.875,
#   'ticker': 'AA'},
#  {'no_of_comments': 6,
# ...

# %%
# Redit API = https://tradestie.com/apps/reddit/api/

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 221000,
# ...

# %%
msft.sustainability
# Out:
#                                      Value
# 2022-8
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           8.39
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                              105
# governanceScore                       5.33
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             15.24
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...
